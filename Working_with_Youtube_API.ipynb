# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#Keys
API_KEY = "AIzaSyDlv4SrJ_LjF5gF8ACwvlkpInKKYrQSTfA"
CHANNEL_ID = "UC7IMq6lLHbptAnSucW1pClA"

# %% [markdown]
# # We are grabing
# 1. List of videos from channel
# - Video ID
# - Video Title
# - Publish Date
# 2. Video Metrics
# - View count
# - Like count
# - Dislike count
# - Comment count

# %%
# make API call
# TO get the youtube HTTPS url go to this link https://developers.google.com/youtube/v3/docs/search/list#http-request
pageToken = ''
URL = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken
response = requests.get(URL).json()
response
# Out:
# {'etag': 'eTjgqUfCDg7UW5xyfTdoh15kv4Y',
#  'items': [{'etag': 'Zvi9YIXaL-jYBc5UQPvsZGoT2_M',
#    'id': {'kind': 'youtube#video', 'videoId': 'm7mtxIhQpc4'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC7IMq6lLHbptAnSucW1pClA',
#     'channelTitle': 'FilterCopy',
#     'description': 'Do you want a partner like AI - Yoush? Follow us on Instagram ➡️ http://bit.ly/FCGram Producer Shreya Agarwal Writer Mallika ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-14T07:00:15Z',
#     'publishedAt': '2021-12-14T07:00:15Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/m7mtxIhQpc4/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/m7mtxIhQpc4/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/m7mtxIhQpc4/mqdefault.jpg',
#       'width': 320}},
# ...

# %%
youtube_data = pd.DataFrame(columns=["video_ID","video_Title","Upload_date","View_Count","Like_Count","Favorite_Count","Comment_Count"])
#We want videoId
# Items->firstvideo[0]->'id'->videoId
for video in response['items']:
  if video['id']['kind'] == "youtube#video":
    video_id = video['id']['videoId']
    video_title = video['snippet']['title']
    video_title = str(video_title).replace('&amp;', "")
    upload_date = video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]
    
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    favorite_count = response_video_stats['items'][0]['statistics']['favoriteCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']

    # save data in pandas df
    youtube_data = youtube_data.append({
        'video_ID' : video_id,
        'video_Title' : video_title,
        'Upload_date' : upload_date,
        'View_Count' : view_count,
        'Like_Count' : like_count,
        'Favorite_Count' : favorite_count,
        'Comment_Count' : comment_count
    }, ignore_index=True)

# This is how you nevigate through the json object to get the values

# %%
youtube_data
# Out:
#        video_ID  ... Comment_Count
# 0   m7mtxIhQpc4  ...           462
# 1   GB4H4Oswq_U  ...           250
# 2   q4y3B1FWugg  ...           877
# 3   vXa48JcUSKU  ...           111
# 4   bAur7SlX0Z8  ...            96
# 5   Mqwn8ai17w8  ...           360
# 6   -fPS5lP7JXo  ...           206
# 7   to88nRIDNiQ  ...            93
# 8   fWp4_2iuw4w  ...           960
# 9   R2x244LClOw  ...          1391
# 10  PwF66okj180  ...           134
# 11  idrQPi1HDZs  ...           674
# 12  l7YbGOv-8oU  ...           667
# 13  z1s7iybCDtc  ...           138
# 14  L6bXpdqB1s4  ...          1284
# 15  joGb9o1-log  ...          1877
# 16  OUgkb2_7bJQ  ...           159
# 17  TngLevtn45c  ...          1362
# 18  x4pnS6dqJqc  ...          1315
# 19  9PQfMPqgde0  ...           729
# 20  ww3sj63ZE5I  ...          1888
# 21  Mxh1NkmRovE  ...           119
# 22  nmXihu3iRRI  ...          1072
# 23  iYT0M64gTds  ...           712
# 24  TgfiEjQI-bo  ...           194
# 25  pS5-EBv6Gyg  ...           968
# ...
